# %% [markdown]
# # Day 02 of Data Analysis

# %% [markdown]
# ### Creating Dataframes Using Pandaas

# %% [markdown]
# #### Todays's Task:
# 1-Missing Values Check
#
# 2-Detect missing values
#
# 3-Count missing values per column

# %%
import pandas as pd

# %%
my_data = pd.read_csv(r"C:\Users\aslam\Downloads\data_science_practice_40_rows.csv")

# %%
my_data.head(10)
# Out:
#      Name  Age        City  Monthly_Salary  Experience_Years
# 0     Ali   35  Faisalabad           70842               1.6
# 1    Sara   35  Rawalpindi           80260               2.2
# 2   Ahmed   22  Rawalpindi           80179               2.7
# 3  Ayesha   24     Karachi           47863               6.8
# 4   Usman   32  Faisalabad           74367               4.0
# 5  Hassan   40  Rawalpindi           85198               1.9
# 6  Fatima   22  Faisalabad           57473               8.6
# 7   Bilal   20  Faisalabad           64226               5.5
# 8    Zain   35  Faisalabad           96890               7.4
# 9    Hina   21  Faisalabad           73583               5.9

# %%
Average_salary = my_data["Monthly_Salary"].mean() #Calclulating the mean that is also called as Average

# %%
print (f"The Average Salary of the person are {int( Average_salary)} thanks ") #Printing the result Using F strings
# Out:
# The Average Salary of the person are 77381 thanks

# %%
Maximum_salary = my_data["Monthly_Salary"].max() #Calculating the Max Valuse Using Max Function

# %%
print(f"The maximun salry of the person is {int( Maximum_salary )}")
# Out:
# The maximun salry of the person is 114935

# %%
Faisalabad_People = my_data[my_data["City"] == "Faisalabad"].shape[0] # Calculating the Number of People form city

# %%
print (f"There are {int(Faisalabad_People)} Faislabadi people in the sheet")
# Out:
# There are 14 Faislabadi people in the sheet

# %% [markdown]
# ## Detect missing values (True or False)

# %%
Missing_Values = my_data.isnull().sum()

# %%
Missing_Values
# Out:
# Name                0
# Age                 0
# City                0
# Monthly_Salary      0
# Experience_Years    0
# dtype: int64
